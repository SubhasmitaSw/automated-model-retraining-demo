# %%
import pandas as pd
import numpy as np

# %%
def introduce_drift(data, drift_features, drift_amount=0.6, random_seed=42):
    np.random.seed(random_seed)
    drifted_data = data.copy()
    
    for feature in drift_features:
        if feature in data.columns:
            drifted_data[feature] += np.random.normal(loc=0, scale=drift_amount, size=data.shape[0])
    
    return drifted_data

# %%
features_to_drift = ['worst texture', 'worst area', 'worst smoothness']

# load the data
X_test = pd.read_csv('../data/X_test.csv')
y_test = pd.read_csv('../data/y_test.csv')
y_train = pd.read_csv('../data/y_train.csv')
X_train = pd.read_csv('../data/X_train.csv')

drifted_data = introduce_drift(X_test, features_to_drift, drift_amount=50)
drifted_data = drifted_data.reset_index(drop = True)

# %%
X_test.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        12.47         18.60           81.09      481.9          0.09965
# 1        18.94         21.31          123.60     1130.0          0.09009
# 2        15.46         19.48          101.70      748.9          0.10920
# 3        12.40         17.68           81.47      467.8          0.10540
# 4        11.54         14.44           74.65      402.9          0.09984
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0            0.1058         0.08005              0.03821         0.1925
# 1            0.1029         0.10800              0.07951         0.1582
# 2            0.1223         0.14660              0.08087         0.1931
# 3            0.1316         0.07741              0.02799         0.1811
# 4            0.1120         0.06737              0.02594         0.1818
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.06373  ...         14.97          24.64            96.05
# 1                 0.05461  ...         24.86          26.58           165.90
# 2                 0.05796  ...         19.26          26.00           124.90
# 3                 0.07102  ...         12.88          22.91            89.61
# 4                 0.06782  ...         12.26          19.68            78.78
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0       677.9            0.1426             0.2378           0.2671
# 1      1866.0            0.1193             0.2336           0.2687
# 2      1156.0            0.1546             0.2394           0.3791
# 3       515.8            0.1450             0.2629           0.2403
# 4       457.8            0.1345             0.2118           0.1797
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0               0.10150          0.3014                  0.08750
# 1               0.17890          0.2551                  0.06589
# 2               0.15140          0.2837                  0.08019
# 3               0.07370          0.2556                  0.09359
# 4               0.06918          0.2329                  0.08134
#
# [5 rows x 30 columns]

# %%
# check the data
drifted_data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        12.47         18.60           81.09      481.9          0.09965
# 1        18.94         21.31          123.60     1130.0          0.09009
# 2        15.46         19.48          101.70      748.9          0.10920
# 3        12.40         17.68           81.47      467.8          0.10540
# 4        11.54         14.44           74.65      402.9          0.09984
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0            0.1058         0.08005              0.03821         0.1925
# 1            0.1029         0.10800              0.07951         0.1582
# 2            0.1223         0.14660              0.08087         0.1931
# 3            0.1316         0.07741              0.02799         0.1811
# 4            0.1120         0.06737              0.02594         0.1818
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.06373  ...         14.97      49.475708            96.05
# 1                 0.05461  ...         24.86      19.666785           165.90
# 2                 0.05796  ...         19.26      58.384427           124.90
# 3                 0.07102  ...         12.88      99.061493            89.61
# 4                 0.06782  ...         12.26       7.972331            78.78
#
#     worst area  worst smoothness  worst compactness  worst concavity  \
# 0   668.281952        -35.622585             0.2378           0.2671
# 1  1881.077367         34.099187             0.2336           0.2687
# 2  1154.264412        -36.363732             0.2394           0.3791
# 3   457.366098         10.967929             0.2629           0.2403
# 4   514.941141          2.413092             0.2118           0.1797
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0               0.10150          0.3014                  0.08750
# 1               0.17890          0.2551                  0.06589
# 2               0.15140          0.2837                  0.08019
# 3               0.07370          0.2556                  0.09359
# 4               0.06918          0.2329                  0.08134
#
# [5 rows x 30 columns]

# %%
X_train['Outcome'] = y_train.reset_index(drop = True)
drifted_data['Outcome'] = y_test.reset_index(drop = True)

drifted_data.to_csv('../data/new_data.csv', index=False)
X_train.to_csv('../data/reference_data.csv', index=False)
